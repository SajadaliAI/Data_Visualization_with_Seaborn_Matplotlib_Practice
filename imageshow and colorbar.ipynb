# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg

# %%
img = mpimg.imread("pie_plot.png")

# %%
img
# Out:
# array([[[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
# ...

# %%
img = mpimg.imread("pie_plot.png")
plt.imshow(img)

# %%
img = mpimg.imread("pie_plot.png")
plt.figure(figsize = (16,9))
plt.axis("off")
plt.imshow(img)
plt.show()

# %%
single_channel = img [:,:,1]
img = mpimg.imread("pie_plot.png")
plt.figure(figsize = (16,9))
plt.axis("off")
plt.imshow(single_channel, cmap = "hot")
plt.show()

# %%
img2 = mpimg.imread("D:\hello\Sajid.jpg")
plt.imshow(img2)
plt.colorbar()
plt.axis("off")
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\Sajjad\AppData\Local\Temp\ipykernel_6616\2721624927.py:1: SyntaxWarning: invalid escape sequence '\h'
#   img2 = mpimg.imread("D:\hello\Sajid.jpg")

# %%
single_channel_img = img2 [:,:,1]
plt.imshow(single_channel_img, cmap = "hot")
plt.figure(figsize = (16,9))
plt.axis("off")
plt.show()

# %%
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r',
# ...

# %%
cmap_list = ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 'Greens_r', 'Greys_r', 'OrRd_r', 'Oranges_r', 'PRGn_r', 'PiYG_r', 'PuBu_r', 'PuBuGn_r', 'PuOr_r', 'PuRd_r', 'Purples_r', 'RdBu_r', 'RdGy_r', 'RdPu_r', 'RdYlBu_r', 'RdYlGn_r', 'Reds_r', 'Spectral_r', 'Wistia_r', 'YlGn_r', 'YlGnBu_r', 'YlOrBr_r', 'YlOrRd_r', 'afmhot_r', 'autumn_r', 'binary_r', 'bone_r', 'brg_r', 'bwr_r', 'cool_r', 'coolwarm_r', 'copper_r', 'cubehelix_r', 'flag_r', 'gist_earth_r', 'gist_gray_r', 'gist_heat_r', 'gist_ncar_r', 'gist_rainbow_r', 'gist_stern_r', 'gist_yarg_r', 'gnuplot_r', 'gnuplot2_r', 'gray_r', 'hot_r', 'hsv_r', 'jet_r', 'nipy_spectral_r', 'ocean_r', 'pink_r', 'prism_r', 'rainbow_r', 'seismic_r', 'spring_r', 'summer_r', 'terrain_r', 'winter_r', 'Accent_r', 'Dark2_r', 'Paired_r', 'Pastel1_r', 'Pastel2_r', 'Set1_r', 'Set2_r', 'Set3_r', 'tab10_r', 'tab20_r', 'tab20b_r', 'tab20c_r']

# %%
cmap_list
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
# ...

# %%
save_img = []
for i in range (len(cmap_list)):
    save_img.append("d:\\Majid\\\_"+"M_Ali_"+cmap_list[i]+".png")
    print(save_img[i])
# Out:
# d:\Majid\\_M_Ali_magma.png
# d:\Majid\\_M_Ali_inferno.png
# d:\Majid\\_M_Ali_plasma.png
# d:\Majid\\_M_Ali_viridis.png
# d:\Majid\\_M_Ali_cividis.png
# d:\Majid\\_M_Ali_twilight.png
# d:\Majid\\_M_Ali_twilight_shifted.png
# d:\Majid\\_M_Ali_turbo.png
# d:\Majid\\_M_Ali_Blues.png
# d:\Majid\\_M_Ali_BrBG.png
# d:\Majid\\_M_Ali_BuGn.png
# d:\Majid\\_M_Ali_BuPu.png
# d:\Majid\\_M_Ali_CMRmap.png
# d:\Majid\\_M_Ali_GnBu.png
# d:\Majid\\_M_Ali_Greens.png
# d:\Majid\\_M_Ali_Greys.png
# d:\Majid\\_M_Ali_OrRd.png
# d:\Majid\\_M_Ali_Oranges.png
# d:\Majid\\_M_Ali_PRGn.png
# d:\Majid\\_M_Ali_PiYG.png
# d:\Majid\\_M_Ali_PuBu.png
# d:\Majid\\_M_Ali_PuBuGn.png
# d:\Majid\\_M_Ali_PuOr.png
# d:\Majid\\_M_Ali_PuRd.png
# d:\Majid\\_M_Ali_Purples.png
# d:\Majid\\_M_Ali_RdBu.png
# d:\Majid\\_M_Ali_RdGy.png
# d:\Majid\\_M_Ali_RdPu.png
# d:\Majid\\_M_Ali_RdYlBu.png
# d:\Majid\\_M_Ali_RdYlGn.png
# d:\Majid\\_M_Ali_Reds.png
# d:\Majid\\_M_Ali_Spectral.png
# d:\Majid\\_M_Ali_Wistia.png
# ...

# %%
for i in range(len(cmap_list)):
    cmap_name = cmap_list [i]
    plt.figure(figsize= (16,9))
    plt.axis("off")
    print(cmap_name)
    plt.imshow(single_channel_img, cmap= cmap_name)
    print(save_img[i])
    plt.savefig(save_img[i], orientation = "portrate", facecolor = "k")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for i in range(len(cmap_list)):
#       2     cmap_name = cmap_list [i]
#       3     plt.figure(figsize= (16,9))
#
# NameError: name 'cmap_list' is not defined
