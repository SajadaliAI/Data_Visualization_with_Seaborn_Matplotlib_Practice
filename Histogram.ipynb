# %% [markdown]
# # We have generated 2 students date Using Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
ml_students_age = np.random.randint(18,45,(100))
py_students_age = np.random.randint(15,40,(100))

# %%
print(ml_students_age)
print(py_students_age)
# Out:
# [40 39 33 20 32 35 19 19 27 27 23 34 37 33 22 37 43 32 27 33 30 27 27 43
#  39 18 24 36 19 26 42 26 40 28 27 44 33 32 25 31 25 32 32 37 30 28 44 26
#  25 43 21 28 18 20 21 38 39 18 25 21 41 22 18 39 44 27 19 34 23 35 22 36
#  43 23 24 31 43 20 29 22 42 21 36 29 43 30 23 34 39 34 38 25 29 43 33 29
#  30 36 25 33]
# [17 36 16 20 34 29 19 21 38 35 37 24 34 17 33 15 39 29 19 31 36 19 17 21
#  27 22 17 29 15 38 20 18 36 28 25 25 23 19 28 16 36 35 36 37 32 35 23 27
#  29 26 33 29 31 36 34 18 22 32 19 15 39 28 33 16 34 21 25 35 31 35 30 19
#  30 26 29 25 37 31 25 39 18 38 19 15 27 38 25 18 16 30 35 35 22 27 38 20
#  23 16 37 37]

# %%
plt.hist(ml_students_age)
plt.title("ML Students Histogram")
plt.xlabel("Students Age Catogery")
plt.ylabel("No. Students Age")
# Out:
# Text(0, 0.5, 'No. Students Age')

# %%
bins = [15,20,25,30,35,40,45]
plt.hist(ml_students_age, bins, rwidth = 0.8,histtype = "bar",orientation = "vertical",color = "m",
        label = "ML students")
plt.title("ML Students Histogram")
plt.xlabel("Students Age Catogery")
plt.ylabel("No. Students Age")
plt.legend()

# %%
plt.figure(figsize=(16,8))
bins = [15,20,25,30,35,40,45]
plt.hist([ml_students_age,py_students_age], bins, rwidth = 0.8,histtype = "bar",orientation = "vertical",
         color = ["m","g"],label = "ML students")

plt.title("ML Students Histogram")
plt.xlabel("Students Age Catogery")
plt.ylabel("No. Students Age")
plt.legend()

# %%
from matplotlib import style
style.use("ggplot")
bins = [15,20,25,30,35,40,45]
plt.hist([ml_students_age,py_students_age], bins, rwidth = 0.8,histtype = "bar",orientation = "vertical",
         color = ["m","g"],label = "ML students")

plt.title("ML Students Histogram")
plt.xlabel("Students Age Catogery")
plt.ylabel("No. Students Age")
plt.legend()
